# %% [markdown]
# # Annotate with DReAMy: NER, SA, RE
#
# In this notebook, we will use DReAMy and its default setting to quickly annotate a set of dream reports.

# %%
! pip install dreamy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: dreamy in /usr/local/lib/python3.10/dist-packages (0.1.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from dreamy) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from dreamy) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from dreamy) (1.2.2)
# Requirement already satisfied: transformers[tokenizers,torch] in /usr/local/lib/python3.10/dist-packages (from dreamy) (4.28.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from dreamy) (4.65.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from dreamy) (2.12.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets->dreamy) (0.3.6)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets->dreamy) (6.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->dreamy) (9.0.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->dreamy) (3.8.4)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.10/dist-packages (from datasets->dreamy) (0.18.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets->dreamy) (2.27.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->dreamy) (0.70.14)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from datasets->dreamy) (0.14.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets->dreamy) (23.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->dreamy) (3.2.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets->dreamy) (2023.4.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->dreamy) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->dreamy) (2022.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->dreamy) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->dreamy) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->dreamy) (1.10.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers[tokenizers,torch]->dreamy) (2022.10.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers[tokenizers,torch]->dreamy) (3.12.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers[tokenizers,torch]->dreamy) (0.13.3)
# Requirement already satisfied: torch!=1.12.0,>=1.9 in /usr/local/lib/python3.10/dist-packages (from transformers[tokenizers,torch]->dreamy) (2.0.0+cu118)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->dreamy) (23.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->dreamy) (1.9.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->dreamy) (4.0.2)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->dreamy) (2.0.12)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->dreamy) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->dreamy) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->dreamy) (6.0.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets->dreamy) (4.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->dreamy) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->dreamy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->dreamy) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->dreamy) (1.26.15)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.9->transformers[tokenizers,torch]->dreamy) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.9->transformers[tokenizers,torch]->dreamy) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.9->transformers[tokenizers,torch]->dreamy) (2.0.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.9->transformers[tokenizers,torch]->dreamy) (3.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch!=1.12.0,>=1.9->transformers[tokenizers,torch]->dreamy) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch!=1.12.0,>=1.9->transformers[tokenizers,torch]->dreamy) (16.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch!=1.12.0,>=1.9->transformers[tokenizers,torch]->dreamy) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.12.0,>=1.9->transformers[tokenizers,torch]->dreamy) (1.3.0)

# %%
import dreamy

# %% [markdown]
# Let's start by getting some dreams. You can stard by dowloading a collection of dream-reports scraped from the DreamBank database, freely availabe from DReAMy's hugging face!
#
# DReAMy has direct access to two datasets. A smaller English-only (~ 20k), and a larger and multiplingual one (En/De, ~ 30 k). We will start with the En-Only one, has it has descriptive variables (such as gender and year).

# %%
# choose between base (~ 22k reports, EN-only & more descriptive variables) 
# large (~ 29k reports, reports in EN and De, only series as descriptive variables)
database  = "base" 
dream_bank = dreamy.get_HF_DreamBank(database=database, as_dataframe=True)
# Out:
# WARNING:datasets.builder:Found cached dataset parquet (/root/.cache/huggingface/datasets/DReAMy-lib___parquet/DReAMy-lib--DreamBank-dreams-en-98a9abc92d226c3a/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# As you can see, the file, dowloaded directlty as a pandas DataFrame, as three entires:
# - dreams, the dream-reports
# - series, the different collection of DreamBank
# - description, a brief description of each series

# %%
dream_bank.sample(2)
# Out:
#         series                   description  \
# 3577  dorothea  Dorothea: 53 years of dreams
# 8510        b2               Barb Sanders #2
#
#                                                  dreams  gender       year
# 3577                     With someone planning a party.  female  1912-1965
# 8510  (08/03/00)["Poison frog prisoner bites me."] I...  female  1997-2001

# %% [markdown]
# Lets now sample a small set of dreams. If you have a more powerfull machine (or you are working on Colab), you can increase the number of report. Note than the whole dataset contains ~ 29 k reports.

# %%
n_samples = 1000
dream_sample = dream_bank.sample(n_samples).reset_index(drop=True)

list_of_reports = dream_sample["dreams"].tolist()

# %% [markdown]
# First, we can check the suit of models you can call via dreamy to annotate dream reports. Remember that dreamy has three main annotation tasks:
#
#  - NER : (name entity recognition) which annotates reports with respect to the character appearing in a report.
#
# - SA: (sentiment analysis) which annotates reports with respect to which of the five Hall & Van de Castle emotions (anger, apprehension, confusion, sadn4ssm happiness) appear in a report (possibly, also which character is experiencing them)
#
# - RE: (relation extraction), which extracts entities (characters) in a report and the relation between them. At the moment, the only RE task available refers to the activity feature of the HVDC framework.
#
# To check which models are available for download, just call the `show_models()` method. This will return a list of `Task, model_description: model_name` strings. As it will be shortly more, `dreamy` has default-setted models, based on performance, but you can always switch between them.

# %%
dreamy.show_models()
# Out:
# {'NER, EN-only, base, generation of list of (interpretable characters). T5)': 'DReAMy-lib/t5-base-DreamBank-Generation-NER-Char',
#  'SA, En-only, large, multi-label classification. Custom architecture from Bertolini et al., 2023': 'DReAMy-lib/DB-custom-architecture',
#  'SA, Multilingual (94), large, multi-label classification. XLM-RoBERTa': 'DReAMy-lib/xlm-roberta-large-DreamBank-emotion-presence',
#  'SA, En-only, base, multi-label classification. BERT-base-cased': 'DReAMy-lib/bert-base-cased-DreamBank-emotion-presence',
#  'SA, En-only, base, generation of emotion and character experiencing them. T5': 'DReAMy-lib/t5-base-DreamBank-Generation-Emot-Char',
#  'SA, En-only, base, generation of emotion with ammount of presence. T5': 'DReAMy-lib/t5-base-DreamBank-Generation-Emot-EmotNn',
#  'RE, EN-only, base, generation of  (initialiser : activity type : receiver) list. T5)': 'DReAMy-lib/t5-base-DreamBank-Generation-Act-Char'}

# %% [markdown]
# To check which are the default mdoels for each task, call the `.show_default_models()` method.

# %%
dreamy.show_default_models()
# Out:
# {'NER': 'DReAMy-lib/t5-base-DreamBank-Generation-NER-Char',
#  'SA': 'DReAMy-lib/xlm-roberta-large-DreamBank-emotion-presence',
#  'RE': 'DReAMy-lib/t5-base-DreamBank-Generation-Act-Char'}

# %% [markdown]
# # Annotation with *default* settings
# ## NER

# %% [markdown]
# Now we can start annotate our dream reports. We will start with the manin task: NER.
#
# First, we need to specify such task (the default is `SA`), and ser other minor varubaels, like batch size and which device to use. Lastly, we need a list of reports. We will use the one previosly defined.model_name

# %%
task       = "NER"
batch_size = 16
device     = 0  # "cpu" for local "cuda" or device number (e.g., 0) for GPU

# %%
NER_annotations = dreamy.annotate_reports(
    list_of_reports, 
    task=task, 
    device=device,
    batch_size=batch_size,
)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/2.35k [00:00<?, ?B/s]
# Downloading spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
#   2%|▏         | 1/63 [00:03<03:24,  3.30s/it]Token indices sequence length is longer than the specified maximum sequence length for this model (1203 > 512). Running this sequence through the model will result in indexing errors
# 1000it [02:42,  6.15it/s]

# %%
NER_annotations[:10]
# Out:
# ['individual female known adult; group joint uncertian adult;',
#  'individual male husband adult; unknown character;',
#  'group joint uncertian adult;',
#  'individual male known adult; individual male known adult;',
#  'individual female mother adult; individual male father adult; unknown character; individual female known teenager; individual male stranger adult; group joint known teenager;',
#  'individual female known adult; individual male uncertian adult; individual male known adult; individual male known adult; group male uncertian adult; group joint parents adult;',
#  'individual female mother adult; individual female daughter adult;',
#  'individual male known adult; group joint uncertian adult; individual female uncertian adult;',
#  'individual male stranger adult;',
#  'group female stranger adult; individual female occupational adult;']

# %% [markdown]
# ## SA

# %% [markdown]
# We can do the exact same the same for SA task. However, not that the SA task allows for both a generation (e.g., `individual male occupational adult experienced sadness, ...`) and multi-label classification settings (e.g., `{label: AN, score:.98,...`). This last setting has two settings itself. The default one, `distribution`, where the output contains each of the five emotions (i.e., `label`) *and* the probability associated by the model to each emotion (i.e., `score`). Or a second one, `present`, where the output will have a list form, containing only those emotions that the model was trained to predict "as truly present" – that is, labels with a `score` > .5.

# %%
task        = "SA"
output_type = "distribution"
batch_size = 16
device     = 0  # "cpu" for local, "cuda" or device number (e.g., 0) for GPU

# %%
SA_predictions = dreamy.annotate_reports(
    list_of_reports, 
    task=task, 
    device=device,
    batch_size=batch_size, 
    return_type=output_type,
)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/951 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/452 [00:00<?, ?B/s]
# Downloading (…)tencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# 1000it [01:32, 10.83it/s]

# %%
SA_predictions[:10]
# Out:
# [[{'label': 'CO', 'score': 0.03959300369024277},
#   {'label': 'AN', 'score': 0.019475437700748444},
#   {'label': 'HA', 'score': 0.01309686154127121},
#   {'label': 'AP', 'score': 0.011727494187653065},
#   {'label': 'SD', 'score': 0.004194930661469698}],
#  [{'label': 'HA', 'score': 0.9959113597869873},
#   {'label': 'AP', 'score': 0.9071735143661499},
#   {'label': 'CO', 'score': 0.8760898113250732},
#   {'label': 'AN', 'score': 0.1336604654788971},
#   {'label': 'SD', 'score': 0.04185082018375397}],
#  [{'label': 'AP', 'score': 0.9984740614891052},
#   {'label': 'HA', 'score': 0.9069458842277527},
#   {'label': 'SD', 'score': 0.03238131105899811},
#   {'label': 'AN', 'score': 0.00880750734359026},
#   {'label': 'CO', 'score': 0.007660091854631901}],
#  [{'label': 'AP', 'score': 0.9968907237052917},
#   {'label': 'HA', 'score': 0.21021009981632233},
#   {'label': 'SD', 'score': 0.005786903668195009},
#   {'label': 'CO', 'score': 0.0030503757297992706},
#   {'label': 'AN', 'score': 0.002490844577550888}],
#  [{'label': 'SD', 'score': 0.9893390536308289},
#   {'label': 'CO', 'score': 0.3285013437271118},
#   {'label': 'AP', 'score': 0.07579527795314789},
#   {'label': 'HA', 'score': 0.011717474088072777},
#   {'label': 'AN', 'score': 0.00467269029468298}],
#  [{'label': 'AP', 'score': 0.6058486700057983},
#   {'label': 'AN', 'score': 0.2273620367050171},
#   {'label': 'CO', 'score': 0.007028824649751186},
#   {'label': 'SD', 'score': 0.003062748583033681},
#   {'label': 'HA', 'score': 0.0025593512691557407}],
#  [{'label': 'SD', 'score': 0.9969498515129089},
#   {'label': 'AP', 'score': 0.601921021938324},
#   {'label': 'AN', 'score': 0.024232853204011917},
#   {'label': 'HA', 'score': 0.009610709734261036},
#   {'label': 'CO', 'score': 0.004318167921155691}],
#  [{'label': 'AP', 'score': 0.9943634271621704},
#   {'label': 'SD', 'score': 0.005651099607348442},
#   {'label': 'CO', 'score': 0.004845051094889641},
#   {'label': 'AN', 'score': 0.0035691047087311745},
#   {'label': 'HA', 'score': 0.0035373815335333347}],
#  [{'label': 'AN', 'score': 0.9913144707679749},
#   {'label': 'HA', 'score': 0.010393272154033184},
#   {'label': 'SD', 'score': 0.008753200061619282},
#   {'label': 'CO', 'score': 0.006823986768722534},
#   {'label': 'AP', 'score': 0.00592272263020277}],
#  [{'label': 'CO', 'score': 0.9972666501998901},
#   {'label': 'HA', 'score': 0.021000955253839493},
#   {'label': 'AP', 'score': 0.01577848196029663},
#   {'label': 'SD', 'score': 0.008145203813910484},
#   {'label': 'AN', 'score': 0.006883037276566029}]]

# %% [markdown]
# ## RE
# Lastly, we look at the relation extraction task. The procedure is one again the same, we just have to set the `task` argument, like so.

# %%
task       = "RE"
batch_size = 16
device     = 0  # "cpu" for local, "cuda" or device number (e.g., 0) for GPU

# %%
RE_annotations = dreamy.annotate_reports(
    list_of_reports, 
    task=task, 
    device=device,
    batch_size=batch_size,
)
# Out:
#   0%|          | 0/63 [00:00<?, ?it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (519 > 512). Running this sequence through the model will result in indexing errors
# 1000it [04:56,  3.37it/s]

# %%
RE_annotations[:10]
# Out:
# ['(dreamer : alone location : none), (dreamer : alone location : none), (dreamer : alone physical : none), (dreamer : verbal towards : individual female mother adult), (individual female mother adult : verbal reciprocated : dreamer), (dreamer : alone verbal : none)',
#  '(dreamer : verbal mutual : individual female wife adult), (dreamer : alone auditory : none), (individual male stranger adult : alone physical : none), (individual male stranger adult : verbal towards : dreamer), (dreamer : alone auditory : none), (individual female stranger adult : alone physical : none), (dreamer : alone physical : none), (dreamer : verbal towards : individual female stranger adult), (individual female stranger adult : verbal reciprocated : dreamer), (',
#  '(dreamer : alone movement : none), (dreamer : alone movement : none), (dreamer : alone visual : none), (dreamer : alone visual : none), (dreamer : alone physical : none), (dreamer : alone visual : none)',
#  '(dreamer : alone physical : none), (dreamer : alone visual : none), (dreamer : alone visual : none), (individual indefinite uncertian adult : verbal towards : dreamer)',
#  '(dreamer and individual male known adult : alone physical : none), (dreamer and individual male occupational adult : verbal towards : individual male occupational adult), (individual male occupational adult : verbal reciprocated : dreamer), (dreamer : verbal reciprocated : individual male occupational adult), (dreamer and individual male occupational adult : alone movement : none), (dreamer and individual male occupational adult : alone visual : none), (dreamer and individual male occupational adult : alone visual : none)',
#  '(dreamer : alone visual : none)',
#  '(dreamer : alone movement : none), (group female uncertian adult : alone verbal : none), (individual female uncertian adult : alone physical : none), (individual female uncertian adult : alone visual : none), (individual female uncertian adult : verbal towards : dreamer), (dreamer : alone physical : none), (group female uncertian adult : alone movement : none), (individual female uncertian adult : verbal towards : dreamer), (dreamer : alone',
#  '(dreamer : alone movement : none), (dreamer : verbal towards : individual female uncertian adult), (dreamer : alone physical : none), (dreamer : alone thinking : none)',
#  '(dreamer : alone location : none)',
#  '(dreamer : physical towards : individual male known adult), (individual male known adult : verbal towards : dreamer), (dreamer : verbal reciprocated : individual male known adult), (dreamer and individual male known adult : alone movement : none), (dreamer : alone physical : none), (dreamer : verbal towards : individual male known adult), (individual male known adult : alone physical : none), (dreamer : alone movement : none), (dreamer : alone visual : none), (dreamer']
